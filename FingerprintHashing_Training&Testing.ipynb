# %%
from os import path
# If running on colab: the first time download and unzip additional files
#!unzip '/content/drive/MyDrive/SocoFing.zip'

# %%
import math
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from ipywidgets import interact
import os

import argparse
import sys
from os import listdir
from os.path import isfile, join
from typing import Dict, List, Tuple

import imagehash
import numpy as np
from PIL import Image
from aiohttp import Fingerprint

# %% [markdown]
# ###Encoding Keypoint information with D-Hash

# %%
count2,negc2=0,0
fing1,fing2=0,0
sift = cv.SIFT_create()
def minutiae_hash(m1):
    test=np.full((97), False, dtype=bool)
    test2=np.full((104), False, dtype=bool)
    for i in range(len(m1)):
        t1 = m1[i][0]
        t2 = m1[i][1]

        test[t1]=1
        test2[t2]=1
    b2 = np.append(test,test2)
    return b2

def calculate_signature(image_file: str, hash_size: int) -> np.ndarray:
    """
    Calculate the dhash signature of a given file

    Args:
        image_file: the image (path as string) to calculate the signature for
        hash_size: hash size to use, signatures will be of length hash_size^2

    Returns:
        Image signature as Numpy n-dimensional array or None if the file is not a PIL recognized image
    """
    global sift
    filename = image = kp1 = kp2 = mp = None
    hold_cord1=[]
    sig = []
    hash_size2=128
    pil_image = Image.open(image_file).convert("L").resize(
                        (hash_size2+1, hash_size2),
                        Image.ANTIALIAS)
    dhash = imagehash.dhash(pil_image, hash_size2)
    signature = dhash.hash.flatten()
    pil_image.close()

    #fp = cv.imread(image_file, cv.IMREAD_GRAYSCALE)
    #f1, m1, ls1,c1,b1 = identification(fp)
    sample = cv.imread(image_file)
    keypoints_1, des1 = sift.detectAndCompute(sample, None)
    coordinates_1 = [kp.pt for kp in keypoints_1]
    for i, coord in enumerate(coordinates_1):
      hold_cord1.append((int(coord[0]),int(coord[1])))

    mi = minutiae_hash(hold_cord1)
    #sig.append(signature)
    #signature=np.append(signature,signature2)  #[[dhash],[minute]]
    #signature=np.append(signature,signature3)
    sig=np.append(signature,mi)

    #sig=np.append(sig,des1).astype(np.uint8)

    return sig


def find_near_duplicates(input_dir: str, test_sample: str, threshold: float, hash_size: int, bands: int) -> List[Tuple[str, str, float]]:
    """
    Find near-duplicate images

    Args:
        input_dir: Directory with images to check
        threshold: Images with a similarity ratio >= threshold will be considered near-duplicates
        hash_size: Hash size to use, signatures will be of length hash_size^2
        bands: The number of bands to use in the locality sensitve hashing process

    Returns:
        A list of near-duplicates found. Near duplicates are encoded as a triple: (filename_A, filename_B, similarity)
    """
    global count2,fing1,fing2,negc2
    rows: int = 208 #int(hash_size**2/bands) 166
    signatures = dict()
    hash_buckets_list: List[Dict[str, List[str]]] = [dict() for _ in range(bands)]

    # Build a list of candidate files in given input_dir
    for fl in range(len(input_dir)):

        file_list = [join(input_dir[fl], f) for f in listdir(input_dir[fl]) if isfile(join(input_dir[fl], f))]

    # Iterate through all files in input directory
        for fh in file_list:
            if count2 % 100 == 0 : print(count2)
            count2+=1
            try:
                signature = calculate_signature(fh, hash_size)

            except IOError:
            # Not a PIL image, skip this file
                continue

        # Keep track of each image's signature
            signatures[fh] = np.packbits(signature)

        # Locality Sensitive Hashing
            for i in range(bands):
                signature_band = signature[i*rows:(i+1)*rows]
                signature_band_bytes = signature_band.tobytes()
                if signature_band_bytes not in hash_buckets_list[i]:
                    hash_buckets_list[i][signature_band_bytes] = list()
                hash_buckets_list[i][signature_band_bytes].append(fh)

    # Build candidate pairs based on bucket membership
    candidate_pairs = set()
    for hash_buckets in hash_buckets_list:
        for hash_bucket in hash_buckets.values():
            if len(hash_bucket) > 1:
                hash_bucket = sorted(hash_bucket)
                for i in range(len(hash_bucket)):
                    for j in range(i+1, len(hash_bucket)):
                        candidate_pairs.add(tuple([hash_bucket[i],hash_bucket[j]]))

    # Check candidate pairs for similarity
    near_duplicates = list()
    fing1=candidate_pairs
    fing2=signatures
    for cpa, cpb in candidate_pairs:
            subject_id_gender_finger1 = cpa.split('/')[-1].split('_')[0:5]
            subject_id_gender_finger2 = test_sample.split('/')[-1].split('_')[0:5]
            subject_id_gender_finger1_str = '_'.join(subject_id_gender_finger1)
            subject_id_gender_finger2_str = '_'.join(subject_id_gender_finger2)
            #print('1',subject_id_gender_finger1_str)
            #print('2',subject_id_gender_finger2_str)
            if subject_id_gender_finger1_str==subject_id_gender_finger2_str:
                hd = sum(np.bitwise_xor(
                    np.unpackbits(signatures[cpa]),
                    np.unpackbits(signatures[cpb])
                ))
                similarity = (hash_size**2 - hd) / hash_size**2
                #print(similarity)
                #if similarity > threshold:
                near_duplicates.append((cpa, cpb, similarity))

    # Sort near-duplicates by descending similarity and return
    near_duplicates.sort(key=lambda x:x[2], reverse=True)

    return near_duplicates


def main(ip,op):

    input_dir = ip
    test_sample = op           #'/content/New_Folder/7__M_Left_index_finger.BMP'
    threshold = 0.1
    hash_size = 129  #22,8,57
    bands = 80

    flag=0

    try:
        near_duplicates = find_near_duplicates(input_dir, test_sample, threshold, hash_size, bands)
        print('n',near_duplicates)
        if near_duplicates:
            print(f"Found {len(near_duplicates)} near-duplicate images in {input_dir} (threshold {threshold:.2%})")
            for a,b,s in near_duplicates:
                print(f"{s:.2%} similarity: file 1: {a} - file 2: {b}")
            flag=1
            return near_duplicates

        elif flag==0:
            print(f"No near-duplicates found in {input_dir} (threshold {threshold:.2%})")
            return 0

    except OSError:
        print(f"Couldn't open input directory {input_dir}")
        return 0

# %%
xx=calculate_signature('try2/Real/69__M_Left_little_finger.BMP',16)
xx.shape
# Out:
# /tmp/ipykernel_4685/2704621113.py:34: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   Image.ANTIALIAS)
# (16585,)

# %%
iter=0
counter=0
if __name__ == "__main__":

    paths =  ['try2/Real/', 'try2/Altered/Altered-Easy/', 'try2/Altered/Altered-Hard/', 'try2/Altered/Altered-Medium/']
    paths2=['try2i/']
    main(paths, 'try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP')
# Out:
# 0
# /tmp/ipykernel_4685/2638960885.py:34: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   Image.ANTIALIAS)
# 100
# 200
# 300
# 400
# n [('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP', 'try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP', 0.9781263145243675), ('try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP', 'try2/Real/69__M_Right_thumb_finger.BMP', 0.9500630971696412), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP', 'try2/Real/69__M_Right_thumb_finger.BMP', 0.9402079201971035), ('try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP', 'try2/Real/69__M_Right_thumb_finger.BMP', 0.9389459768042786), ('try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP', 'try2/Real/69__M_Right_thumb_finger.BMP', 0.9019890631572622), ('try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP', 'try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP', 0.9010275824770146), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP', 'try2/Real/69__M_Right_thumb_finger.BMP', 0.8963403641608076), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP', 'try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP', 0.8958596238206838), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP', 'try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP', 0.8825190793822487), ('try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP', 'try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP', 0.8724235322396491), ('try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP', 'try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP', 0.8676762213809266), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP', 'try2/Real/69__M_Right_thumb_finger.BMP', 0.8625082627245959), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP', 'try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP', 0.8605853013641007), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP', 'try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP', 0.8599843759389459), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP', 'try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP', 0.8536145664323057), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP', 'try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP', 0.8481461450633976), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP', 'try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP', 0.8470043867556036), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP', 'try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP', 0.8434589267471907), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP', 'try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP', 0.8417763355567575), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP', 'try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP', 0.8401538369088396), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP', 'try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP', 0.8236283877170844), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP', 'try2/Real/101__M_Right_little_finger.BMP', 0.6696712937924404), ('try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP', 'try2/Real/101__M_Left_index_finger.BMP', 0.6648037978486869), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP', 'try2/Altered/Altered-Medium/69__M_Left_index_finger_Obl.BMP', 0.6648037978486869), ('try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP', 'try2/Real/101__M_Left_index_finger.BMP', 0.6642629649660478), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP', 'try2/Altered/Altered-Hard/7__M_Left_index_finger_Obl.BMP', 0.6634216693708311), ('try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP', 'try2/Real/101__M_Right_little_finger.BMP', 0.6633615768283156), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP', 'try2/Real/101__M_Left_index_finger.BMP', 0.6633615768283156), ('try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP', 'try2/Real/101__M_R ...
# Found 999 near-duplicate images in ['try2/Real/', 'try2/Altered/Altered-Easy/', 'try2/Altered/Altered-Hard/', 'try2/Altered/Altered-Medium/'] (threshold 10.00%)
# 97.81% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP
# 95.01% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/69__M_Right_thumb_finger.BMP
# 94.02% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/69__M_Right_thumb_finger.BMP
# 93.89% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/69__M_Right_thumb_finger.BMP
# 90.20% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/69__M_Right_thumb_finger.BMP
# 90.10% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP
# 89.63% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/69__M_Right_thumb_finger.BMP
# 89.59% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP
# 88.25% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP
# 87.24% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP
# 86.77% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP
# 86.25% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/69__M_Right_thumb_finger.BMP
# 86.06% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP
# 86.00% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP
# 85.36% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP
# 84.81% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP
# 84.70% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP
# 84.35% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP
# 84.18% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP
# 84.02% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP
# 82.36% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP
# 66.97% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/101__M_Right_little_finger.BMP
# 66.48% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/101__M_Left_index_finger.BMP
# 66.48% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/69__M_Left_index_finger_Obl.BMP
# 66.43% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/101__M_Left_index_finger.BMP
# 66.34% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_index_finger_Obl.BMP
# 66.34% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/101__M_Right_little_finger.BMP
# 66.34% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/101__M_Left_index_finger.BMP
# 66.28% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/101__M_Right_little_finger.BMP
# 66.28% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/6__M_Left_little_finger_Zcut.BMP
# 66.20% similarity: file 1: try2/Real/69__M_Right_thumb_finger.BMP - file 2: try2/Real/7__M_Right_ring_finger.BMP
# 66.19% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/6__M_Left_little_finger_Obl.BMP
# 66.17% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_ring_finger_Obl.BMP
# 66.15% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/7__M_Right_ring_finger.BMP
# 66.13% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/8__M_Left_little_finger.BMP
# 66.13% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/6__M_Left_little_finger_Obl.BMP
# 66.11% similarity: file 1: try2/Real/69__M_Right_thumb_finger.BMP - file 2: try2/Real/7__M_Right_little_finger.BMP
# 66.07% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/6__M_Left_little_finger_CR.BMP
# 66.01% similarity: file 1: try2/Real/69__M_Right_thumb_finger.BMP - file 2: try2/Real/7__M_Left_little_finger.BMP
# 65.99% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/101__M_Right_little_finger.BMP
# 65.99% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/101__M_Left_index_finger.BMP
# 65.99% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_ring_finger_CR.BMP
# 65.98% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/101__M_Right_little_finger.BMP
# 65.96% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/7__M_Right_ring_finger.BMP
# 65.96% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/101__M_Left_index_finger.BMP
# 65.96% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/101__M_Left_index_finger.BMP
# 65.92% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/8__M_Left_little_finger_Obl.BMP
# 65.91% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/6__M_Left_little_finger_CR.BMP
# 65.91% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/101__M_Right_little_finger.BMP
# 65.90% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_little_finger_CR.BMP
# 65.89% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/8__M_Right_little_finger_CR.BMP
# 65.88% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_little_finger_CR.BMP
# 65.87% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/7__M_Left_little_finger.BMP
# 65.85% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/6__M_Left_little_finger_Zcut.BMP
# 65.85% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_little_finger_Obl.BMP
# 65.84% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/6__M_Left_middle_finger_Obl.BMP
# 65.84% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_little_finger_CR.BMP
# 65.84% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_little_finger_CR.BMP
# 65.83% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/7__M_Left_little_finger.BMP
# 65.82% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/7__M_Right_little_finger.BMP
# 65.80% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/7__M_Right_little_finger.BMP
# 65.76% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_little_finger_CR.BMP
# 65.75% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/9__M_Left_index_finger_Obl.BMP
# 65.74% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_little_finger_CR.BMP
# 65.74% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/8__M_Left_little_finger_CR.BMP
# 65.70% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/6__M_Left_little_finger_Obl.BMP
# 65.68% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_ring_finger_Obl.BMP
# 65.68% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/69__M_Left_ring_finger_Obl.BMP
# 65.67% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/7__M_Right_little_finger.BMP
# 65.67% similarity: file 1: try2/Real/69__M_Right_thumb_finger.BMP - file 2: try2/Real/8__M_Left_little_finger.BMP
# 65.66% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/8__M_Left_little_finger.BMP
# 65.63% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_little_finger_Zcut.BMP
# 65.63% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/8__M_Right_ring_finger_Obl.BMP
# 65.62% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/7__M_Right_middle_finger.BMP
# 65.62% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_ring_finger_Obl.BMP
# 65.60% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/8__M_Left_little_finger_Obl.BMP
# 65.60% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_ring_finger_CR.BMP
# 65.59% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_Obl.BMP
# 65.59% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/7__M_Left_little_finger.BMP
# 65.59% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/8__M_Right_little_finger_Obl.BMP
# 65.59% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/8__M_Right_little_finger_Obl.BMP
# 65.59% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_Zcut.BMP
# 65.58% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_little_finger_CR.BMP
# 65.58% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/7__M_Right_ring_finger.BMP
# 65.57% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/7__M_Left_little_finger.BMP
# 65.57% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_CR.BMP
# 65.55% similarity: file 1: try2/Real/69__M_Right_thumb_finger.BMP - file 2: try2/Real/7__M_Left_ring_finger.BMP
# 65.55% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_middle_finger_CR.BMP
# 65.55% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_little_finger_Obl.BMP
# 65.55% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/6__M_Left_little_finger_CR.BMP
# 65.55% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/7__M_Right_ring_finger.BMP
# 65.51% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_little_finger_Obl.BMP
# 65.51% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_little_finger_Obl.BMP
# 65.50% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_little_finger_Obl.BMP
# 65.49% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/133__M_Right_index_finger.BMP
# 65.49% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_little_finger_Obl.BMP
# 65.48% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_little_finger_Obl.BMP
# 65.48% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/6__M_Left_little_finger_Zcut.BMP
# 65.47% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_little_finger_Obl.BMP
# 65.46% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/101__M_Right_middle_finger.BMP
# 65.46% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/126__F_Left_little_finger_Zcut.BMP
# 65.45% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/126__F_Left_little_finger_CR.BMP
# 65.45% similarity: file 1: try2/Real/69__M_Right_thumb_finger.BMP - file 2: try2/Real/7__M_Right_middle_finger.BMP
# 65.44% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_little_finger_Obl.BMP
# 65.43% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_index_finger_CR.BMP
# 65.43% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_Obl.BMP
# 65.43% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/8__M_Left_little_finger_CR.BMP
# 65.42% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_Obl.BMP
# 65.40% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/7__M_Right_little_finger.BMP
# 65.40% similarity: file 1: try2/Real/69__M_Right_thumb_finger.BMP - file 2: try2/Real/7__M_Left_middle_finger.BMP
# 65.40% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/69__M_Left_little_finger_Obl.BMP
# 65.38% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_little_finger_Obl.BMP
# 65.37% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_ring_finger_Obl.BMP
# 65.37% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/7__M_Right_middle_finger.BMP
# 65.37% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_little_finger_Zcut.BMP
# 65.34% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_ring_finger_Zcut.BMP
# 65.33% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/133__M_Right_index_finger.BMP
# 65.32% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_index_finger_Obl.BMP
# 65.31% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/7__M_Left_middle_finger.BMP
# 65.31% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_ring_finger_Obl.BMP
# 65.30% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_middle_finger_Obl.BMP
# 65.30% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/8__M_Left_little_finger_CR.BMP
# 65.30% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/8__M_Left_little_finger.BMP
# 65.30% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_ring_finger_CR.BMP
# 65.30% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_little_finger_CR.BMP
# 65.29% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_middle_finger_Obl.BMP
# 65.28% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/6__M_Left_index_finger_Obl.BMP
# 65.28% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/8__M_Left_little_finger.BMP
# 65.28% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/133__M_Right_index_finger.BMP
# 65.28% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/107__M_Left_little_finger_Zcut.BMP
# 65.28% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_little_finger_CR.BMP
# 65.25% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/101__M_Right_middle_finger.BMP
# 65.25% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_CR.BMP
# 65.24% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_CR.BMP
# 65.23% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/126__F_Left_index_finger_Obl.BMP
# 65.22% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_little_finger_Obl.BMP
# 65.21% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_middle_finger_Zcut.BMP
# 65.21% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_little_finger_Obl.BMP
# 65.21% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/126__F_Left_middle_finger.BMP
# 65.20% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_little_finger_Obl.BMP
# 65.20% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/101__M_Right_middle_finger.BMP
# 65.19% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/7__M_Left_ring_finger.BMP
# 65.19% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/8__M_Left_little_finger.BMP
# 65.18% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_Obl.BMP
# 65.17% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/7__M_Right_little_finger.BMP
# 65.16% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/107__M_Left_little_finger_Zcut.BMP
# 65.16% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/126__F_Right_index_finger.BMP
# 65.15% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/7__M_Right_ring_finger.BMP
# 65.15% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_Zcut.BMP
# 65.13% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_index_finger_Obl.BMP
# 65.12% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/7__M_Left_ring_finger.BMP
# 65.12% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_Obl.BMP
# 65.11% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/8__M_Left_little_finger.BMP
# 65.10% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/133__M_Right_index_finger.BMP
# 65.10% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_index_finger_CR.BMP
# 65.09% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/126__F_Left_little_finger_Zcut.BMP
# 65.09% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/101__M_Left_little_finger.BMP
# 65.09% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/7__M_Left_middle_finger.BMP
# 65.09% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_little_finger_CR.BMP
# 65.07% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/101__M_Left_little_finger.BMP
# 65.06% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_CR.BMP
# 65.06% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_CR.BMP
# 65.06% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/126__F_Left_little_finger_CR.BMP
# 65.05% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/126__F_Left_little_finger.BMP
# 65.04% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/126__F_Left_little_finger.BMP
# 65.04% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_index_finger_CR.BMP
# 65.03% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/107__M_Left_little_finger_Obl.BMP
# 65.03% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/8__M_Right_little_finger_CR.BMP
# 65.03% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/7__M_Left_ring_finger.BMP
# 65.03% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/101__M_Left_little_finger.BMP
# 65.03% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_little_finger_Obl.BMP
# 65.02% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_thumb_finger_Obl.BMP
# 65.01% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_little_finger_CR.BMP
# 65.01% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_ring_finger_CR.BMP
# 65.01% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_little_finger_CR.BMP
# 65.01% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/126__F_Left_little_finger_Obl.BMP
# 65.01% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_Zcut.BMP
# 65.01% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_ring_finger_Obl.BMP
# 65.00% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/8__M_Right_little_finger_Obl.BMP
# 65.00% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_ring_finger_Obl.BMP
# 65.00% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_little_finger_Obl.BMP
# 64.99% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_ring_finger_CR.BMP
# 64.99% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/8__M_Left_little_finger_Obl.BMP
# 64.98% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/126__F_Left_little_finger.BMP
# 64.97% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_little_finger_CR.BMP
# 64.97% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_CR.BMP
# 64.97% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/6__M_Right_little_finger_Zcut.BMP
# 64.97% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_middle_finger_CR.BMP
# 64.97% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/7__M_Right_little_finger.BMP
# 64.96% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/7__M_Left_ring_finger.BMP
# 64.96% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/7__M_Left_little_finger.BMP
# 64.95% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_ring_finger_Zcut.BMP
# 64.95% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/7__M_Right_middle_finger.BMP
# 64.95% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_ring_finger_Obl.BMP
# 64.94% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/107__M_Left_little_finger_CR.BMP
# 64.92% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/126__F_Right_index_finger_CR.BMP
# 64.92% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/126__F_Left_little_finger_CR.BMP
# 64.91% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/126__F_Left_thumb_finger_Obl.BMP
# 64.91% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_Zcut.BMP
# 64.91% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/126__F_Right_little_finger_Zcut.BMP
# 64.91% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/126__F_Right_index_finger.BMP
# 64.90% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/7__M_Right_ring_finger.BMP
# 64.89% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/101__M_Left_little_finger.BMP
# 64.89% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/101__M_Left_little_finger.BMP
# 64.89% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_ring_finger_Zcut.BMP
# 64.89% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_Zcut.BMP
# 64.88% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/7__M_Left_middle_finger.BMP
# 64.88% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/126__F_Right_index_finger_Zcut.BMP
# 64.88% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/101__M_Left_little_finger.BMP
# 64.88% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_Obl.BMP
# 64.88% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_ring_finger_CR.BMP
# 64.87% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/6__M_Right_middle_finger_Obl.BMP
# 64.87% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/107__M_Left_little_finger_Obl.BMP
# 64.87% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_ring_finger_Obl.BMP
# 64.86% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/7__M_Right_middle_finger.BMP
# 64.85% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/6__M_Right_middle_finger_Zcut.BMP
# 64.85% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/133__M_Left_little_finger.BMP
# 64.83% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_little_finger_Obl.BMP
# 64.83% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_Zcut.BMP
# 64.83% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/7__M_Left_ring_finger.BMP
# 64.83% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_little_finger_Obl.BMP
# 64.83% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/8__M_Right_little_finger_CR.BMP
# 64.82% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_Obl.BMP
# 64.82% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_ring_finger_Obl.BMP
# 64.80% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_little_finger_CR.BMP
# 64.80% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/6__M_Right_little_finger_Obl.BMP
# 64.79% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/126__F_Right_little_finger_CR.BMP
# 64.79% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/107__M_Left_little_finger_CR.BMP
# 64.78% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/7__M_Left_ring_finger.BMP
# 64.77% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/126__F_Left_little_finger.BMP
# 64.77% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/6__M_Right_middle_finger_Obl.BMP
# 64.77% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/6__M_Right_middle_finger_Obl.BMP
# 64.77% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/7__M_Left_little_finger.BMP
# 64.77% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/126__F_Right_little_finger.BMP
# 64.76% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_thumb_finger_Zcut.BMP
# 64.76% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/101__M_Left_middle_finger.BMP
# 64.76% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_thumb_finger_Obl.BMP
# 64.76% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/133__M_Right_index_finger.BMP
# 64.76% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_CR.BMP
# 64.74% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_CR.BMP
# 64.74% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/126__F_Left_little_finger_Obl.BMP
# 64.74% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Right_little_finger_CR.BMP
# 64.73% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/7__M_Left_middle_finger.BMP
# 64.73% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/101__M_Left_middle_finger.BMP
# 64.73% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/69__M_Left_little_finger_CR.BMP
# 64.73% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_ring_finger_Obl.BMP
# 64.73% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_little_finger_Obl.BMP
# 64.73% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/101__M_Right_middle_finger.BMP
# 64.73% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/126__F_Right_little_finger.BMP
# 64.72% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/126__F_Right_index_finger_Zcut.BMP
# 64.71% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_little_finger_CR.BMP
# 64.71% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_CR.BMP
# 64.71% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_Obl.BMP
# 64.71% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/126__F_Left_index_finger.BMP
# 64.71% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_middle_finger_Obl.BMP
# 64.70% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_Obl.BMP
# 64.70% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/107__M_Right_little_finger_Obl.BMP
# 64.69% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/126__F_Left_index_finger.BMP
# 64.68% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/101__M_Right_thumb_finger.BMP
# 64.68% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_Obl.BMP
# 64.67% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_Zcut.BMP
# 64.67% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_ring_finger_Zcut.BMP
# 64.66% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/107__M_Left_little_finger_Obl.BMP
# 64.66% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_middle_finger_Obl.BMP
# 64.65% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_ring_finger_CR.BMP
# 64.63% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/126__F_Left_middle_finger.BMP
# 64.63% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/133__M_Left_little_finger.BMP
# 64.62% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/126__F_Right_index_finger_CR.BMP
# 64.62% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_middle_finger_Zcut.BMP
# 64.61% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/6__M_Right_little_finger_Obl.BMP
# 64.59% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Right_middle_finger_Zcut.BMP
# 64.59% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_ring_finger_Zcut.BMP
# 64.58% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/101__M_Right_middle_finger.BMP
# 64.58% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/101__M_Right_ring_finger.BMP
# 64.58% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_Obl.BMP
# 64.57% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_Obl.BMP
# 64.56% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/7__M_Right_middle_finger.BMP
# 64.56% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/101__M_Right_middle_finger.BMP
# 64.56% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_CR.BMP
# 64.55% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_middle_finger_Obl.BMP
# 64.55% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/126__F_Right_index_finger.BMP
# 64.55% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_middle_finger_CR.BMP
# 64.53% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/69__M_Left_little_finger.BMP
# 64.53% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/101__M_Left_middle_finger.BMP
# 64.52% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_thumb_finger_Zcut.BMP
# 64.51% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/126__F_Right_little_finger.BMP
# 64.50% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/6__M_Left_index_finger_Obl.BMP
# 64.50% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/133__M_Right_index_finger.BMP
# 64.50% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Left_thumb_finger_Zcut.BMP
# 64.50% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/126__F_Left_middle_finger.BMP
# 64.49% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/7__M_Left_ring_finger_Obl.BMP
# 64.48% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/7__M_Left_middle_finger.BMP
# 64.48% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/7__M_Left_middle_finger.BMP
# 64.47% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/91__F_Right_ring_finger_Obl.BMP
# ...
# 61.13% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Right_ring_finger_Obl.BMP
# 61.12% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_middle_finger_Zcut.BMP
# 61.11% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/133__M_Right_little_finger.BMP
# 61.10% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Right_ring_finger_Obl.BMP
# 61.08% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Right_ring_finger_Obl.BMP
# 61.08% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/69__M_Left_middle_finger_CR.BMP
# 61.07% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Right_ring_finger_Zcut.BMP
# 61.05% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/8__M_Left_middle_finger_Obl.BMP
# 61.03% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Right_ring_finger_Zcut.BMP
# 61.02% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_Zcut.BMP
# 61.01% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Right_ring_finger_CR.BMP
# 60.99% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/8__M_Right_thumb_finger_CR.BMP
# 60.98% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/69__M_Left_middle_finger.BMP
# 60.98% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/69__M_Left_middle_finger_Obl.BMP
# 60.98% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/8__M_Right_thumb_finger_Obl.BMP
# 60.97% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/69__M_Left_middle_finger.BMP
# 60.96% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/133__M_Right_little_finger.BMP
# 60.94% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Right_ring_finger_CR.BMP
# 60.94% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/8__M_Left_middle_finger_Zcut.BMP
# 60.93% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/8__M_Left_middle_finger_Zcut.BMP
# 60.90% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Right_ring_finger_CR.BMP
# 60.89% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_middle_finger_CR.BMP
# 60.89% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_CR.BMP
# 60.84% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Hard/8__M_Left_middle_finger_CR.BMP
# 60.83% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Right_ring_finger_Zcut.BMP
# 60.80% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/8__M_Left_middle_finger_Obl.BMP
# 60.79% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/8__M_Left_middle_finger_Zcut.BMP
# 60.76% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/69__M_Left_middle_finger_Zcut.BMP
# 60.75% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/69__M_Left_middle_finger.BMP
# 60.74% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/69__M_Left_middle_finger_CR.BMP
# 60.74% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Hard/8__M_Left_middle_finger_CR.BMP
# 60.74% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_Obl.BMP
# 60.72% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/69__M_Right_middle_finger_CR.BMP
# 60.71% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_Obl.BMP
# 60.69% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/8__M_Left_middle_finger_CR.BMP
# 60.69% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/69__M_Left_middle_finger_CR.BMP
# 60.69% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_Obl.BMP
# 60.65% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_Zcut.BMP
# 60.63% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_CR.BMP
# 60.60% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/69__M_Left_middle_finger_Zcut.BMP
# 60.57% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/69__M_Left_middle_finger_Zcut.BMP
# 60.56% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/133__M_Right_little_finger.BMP
# 60.51% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/133__M_Right_little_finger.BMP
# 60.50% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_CR.BMP
# 60.46% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/133__M_Right_little_finger.BMP
# 60.45% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Hard/8__M_Right_thumb_finger_Obl.BMP
# 60.42% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_CR.BMP
# 60.42% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_CR.BMP
# 60.41% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_Zcut.BMP
# 60.39% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_Obl.BMP
# 60.31% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_CR.BMP
# 60.29% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_Obl.BMP
# 60.28% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/101__M_Left_thumb_finger.BMP
# 60.27% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_CR.BMP
# 60.25% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_Obl.BMP
# 60.25% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_Zcut.BMP
# 60.25% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_CR.BMP
# 60.25% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_Obl.BMP
# 60.23% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_CR.BMP
# 60.23% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_Obl.BMP
# 60.22% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_Zcut.BMP
# 60.21% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_Obl.BMP
# 60.20% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_Obl.BMP
# 60.20% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_Zcut.BMP
# 60.16% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_CR.BMP
# 60.15% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_Zcut.BMP
# 60.15% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/133__M_Right_middle_finger.BMP
# 60.15% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_CR.BMP
# 60.15% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_Obl.BMP
# 60.15% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_Zcut.BMP
# 60.13% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_Zcut.BMP
# 60.12% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/101__M_Left_thumb_finger.BMP
# 60.12% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_CR.BMP
# 60.11% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_CR.BMP
# 60.10% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_Zcut.BMP
# 60.09% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_Obl.BMP
# 60.06% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/101__M_Left_thumb_finger.BMP
# 60.01% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_Zcut.BMP
# 60.01% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_CR.BMP
# 60.00% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_Obl.BMP
# 59.98% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_CR.BMP
# 59.98% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_Zcut.BMP
# 59.97% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/133__M_Right_middle_finger.BMP
# 59.95% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_Zcut.BMP
# 59.94% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_Zcut.BMP
# 59.94% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/133__M_Right_middle_finger.BMP
# 59.94% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_Zcut.BMP
# 59.92% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_Obl.BMP
# 59.92% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_Zcut.BMP
# 59.90% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Real/133__M_Right_middle_finger.BMP
# 59.89% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_CR.BMP
# 59.89% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_Zcut.BMP
# 59.87% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_index_finger_Obl.BMP
# 59.86% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/101__M_Left_thumb_finger.BMP
# 59.86% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/133__M_Right_middle_finger.BMP
# 59.84% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_Obl.BMP
# 59.81% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_Obl.BMP - file 2: try2/Real/101__M_Left_thumb_finger.BMP
# 59.76% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Zcut.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_Obl.BMP
# 59.70% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_CR.BMP
# 59.68% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/101__M_Left_thumb_finger.BMP
# 59.68% similarity: file 1: try2/Altered/Altered-Hard/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_thumb_finger_CR.BMP
# 59.58% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Real/133__M_Right_middle_finger.BMP
# 59.55% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_Obl.BMP
# 59.40% similarity: file 1: try2/Altered/Altered-Medium/69__M_Right_thumb_finger_CR.BMP - file 2: try2/Altered/Altered-Medium/92__F_Left_middle_finger_Zcut.BMP

# %%
#finger_dict,finger_names
pos_flag,fpos_flag,neg_flag,fneg_flag,final_acc=0,0,0,0,0
count_flag,counter=0,0
tp=0
def matchfunc(ip,threshold):
    global finger_dict, finger_names,tp
    g_cpa = ip
    for cpa, cpb in fing1:
          try:
                subject_id_gender_finger1 = cpa.split('/')[-1].split('_')[0:5]
                subject_id_gender_finger2 = g_cpa.split('/')[-1].split('_')[0:5]
                subject_id_gender_finger1_str = '_'.join(subject_id_gender_finger1)
                subject_id_gender_finger2_str = '_'.join(subject_id_gender_finger2)
                #print('1',subject_id_gender_finger1_str)
                #print('2',subject_id_gender_finger2_str)
                if subject_id_gender_finger1_str==subject_id_gender_finger2_str:
                    hd = sum(np.bitwise_xor(
                        np.unpackbits(fing2[cpa]),
                        np.unpackbits(fing2[cpb])))

                    similarity = (hash_size**2 - hd) / hash_size**2

                    if similarity > threshold:
                        tp+=1
                        near_duplicates.append((g_cpa, cpb, similarity))
                near_duplicates.sort(key=lambda x:x[2], reverse=True)
                return near_duplicates
          except:
                return 0


paths =  ['SOCOFing/Real/', 'SOCOFing/Altered/Altered-Easy/', 'SOCOFing/Altered/Altered-Hard/', 'SOCOFing/Altered/Altered-Medium/']
#paths2 =  ['try2/Real/', 'try2/Altered/Altered-Easy/', 'try2/Altered/Altered-Hard/', 'try2/Altered/Altered-Medium/']
for input_dir in range(len(paths)):
    file_list = [join(paths[input_dir], f) for f in listdir(paths[input_dir]) if isfile(join(paths[input_dir], f))]
    counter+=1
    for fh in file_list:
        count_flag+=1
        #print(paths[input_dir])
        if count_flag % 1000000000==0: print(count_flag,(count_flag/1000000000),'B')

        #temp1 = str(paths[f])
        result2 = main(paths2,fh) #main(paths, 'try2/Altered/Altered-Hard/69__M_Right_thumb_finger_Obl.BMP')
        #print(result2)
        if result2!=0:
            xx = result2[0][0]
            yy = result2[0][1]
            path1 = xx
            path2 = yy

            # Extract the relevant parts from the file paths
            subject_id_gender_finger1iii = path1.split('/')[-1].split('_')[0:6]
            subject_id_gender_finger2iii = path2.split('/')[-1].split('_')[0:6]

            # Join the extracted parts into a single string for comparison
            subject_id_gender_finger1_striii = '_'.join(subject_id_gender_finger1iii)
            subject_id_gender_finger2_striii = '_'.join(subject_id_gender_finger2iii)
            #print(subject_id_gender_finger1_str)
            #print(subject_id_gender_finger2_str)
            # Compare the two strings
            if fh==path1 or fh==path2:
                pos_flag+=1
            else:
                fpos_flag+=1
        else:
            fneg_flag+=1
    print(counter,'/',len(paths),'Folders done.')


print()
print('True Positive:',pos_flag)
print('False Positive:',fpos_flag)
print('True Negative:',neg_flag)
print('False Negative:',fneg_flag)
print('Iterations:',count_flag)
print()
print('Accuracy:',(pos_flag/count_flag))
print('Precision:',(pos_flag/(pos_flag+fpos_flag)))
print('Recall:',(pos_flag/(pos_flag+fneg_flag)))
print('F1 Score:',(2*(((pos_flag/(pos_flag+fpos_flag))*(pos_flag/(pos_flag+fneg_flag)))/(((pos_flag/(pos_flag+fpos_flag))+(pos_flag/(pos_flag+fneg_flag)))))))
# Out:
# 1 / 4 Folders done.
# 1000000000 1 B
# 2 / 4 Folders done.
# 2000000000 2 B
# 3 / 4 Folders done.
# 3000000000 3 B
# 4 / 4 Folders done.
#
# True Positive: 55265
# False Positive: 0
# True Negative: 5
# False Negative: 0
# Iterations: 55270
#
# Accuracy: 0.9999095350099512
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
